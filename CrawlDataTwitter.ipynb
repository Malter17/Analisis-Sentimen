# %% [markdown]
# # Crawl Data Twitter > 1500 Tweets
# The crawling process was done using Tweet-Harvest.

# %%
#@title Twitter Auth Token

twitter_auth_token = '531f8dac636e447bbf141af8880d016aceb6e894'

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v

# %%
# Crawl Data

filename = 'ganjar1.csv'
search_keyword = 'ganjar Setelah pemilu:id'
limit = 1500

# !npx --yes tweet-harvest@2.2.8 -o "{filename}" -s "{search_keyword}" -l {limit} --token {twitter_auth_token}
# Out:
# Welcome to the Twitter Crawler 🕷️
#
# This script uses Chromium Browser to crawl data from Twitter with *your* Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# up to date, audited 4 packages in 1s
#
# found 0 vulnerabilities
# Installing dependencies...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-freefont-ttf is already the newest version (20120503-10build1).
# fonts-liberation is already the newest version (1:1.07.4-11).
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libatk-bridge2.0-0 is already the newest version (2.38.0-3).
# libatk1.0-0 is already the newest version (2.36.0-3build1).
# libatspi2.0-0 is already the newest version (2.44.0-3).
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libnspr4 is already the newest version (2:4.32-3build1).
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcomposite1 is already the newest version (1:0.4.5-1build2).
# libxdamage1 is already the newest version (1:1.1.5-2build2).
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxfixes3 is already the newest version (1:6.0.0-1).
# libxkbcommon0 is already the newest version (1.4.0-1).
# libxrandr2 is already the newest version (2:1.5.2-1build1).
# xfonts-scalable is already the newest version (1:1.0.3-1.2ubuntu1).
# fonts-ipafont-gothic is already the newest version (00303-21ubuntu1).
# fonts-tlwg-loma-otf is already the newest version (1:0.7.3-1).
# fonts-unifont is already the newest version (1:14.0.01-1).
# fonts-wqy-zenhei is already the newest version (0.9.45-8).
# xfonts-cyrillic is already the newest version (1:1.0.5).
# fonts-noto-color-emoji is already the newest version (2.042-0ubuntu0.22.04.1).
# libcups2 is already the newest version (2.4.1op1-1ubuntu4.7).
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdrm2 is already the newest version (2.4.113-2~ubuntu0.22.04.1).
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.2).
# libgbm1 is already the newest version (23.2.1-1ubuntu3.1~22.04.2).
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.2).
# libnss3 is already the newest version (2:3.68.2-0ubuntu1.2).
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libwayland-client0 is already the newest version (1.20.0-1ubuntu0.1).
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.8).
# 0 upgraded, 0 newly installed, 0 to remove and 40 not upgraded.
#
# Opening twitter search page...
#
#
# Filling in keywords: ganjar kalah lang:id
#
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 19
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 37
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 49
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 63
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 76
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 90
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 95
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 110
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 124
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 139
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 145
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 158
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 172
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 187
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 195
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 209
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 228
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 247
# Scrolling more...
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 267
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 286
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 302
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 309
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 322
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 336
#
# --Taking a break, waiting for 10 seconds...
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 352
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 369
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 381
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 389
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 397
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 404
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 418
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 435
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 453
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 469
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 484
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 493
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 507
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 519
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 535
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 549
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 562
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 581
# Scrolling more...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 595
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 605
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 617
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 625
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 639
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 654
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 665
#
# --Taking a break, waiting for 10 seconds...
#
# Got some tweets, saving to file...
# Your tweets saved to: /content/tweets-data/ganjar1.csv
# Total tweets saved: 675
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@68f047066632ed8a04abc5582cbb8770"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
#
# Got some tweets, saving to file...
# Error parsing response json: {"_type":"Response","_guid":"response@62c613648cae4ac35745bf428499550d"}
# Most likely, you have already exceeded the Twitter rate limit. Read more on https://twitter.com/elonmusk/status/1675187969420828672?s=46.
# page.waitForTimeout: Target page, context or browser has been closed
#     at /root/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:158:79
#     at step (/root/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:56:23)
#     at Object.next (/root/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:37:53)
#     at step (/root/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:41:139)
#     at Object.next (/root/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:37:53)
#     at fulfilled (/root/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:28:58)
# Keywords: ganjar kalah lang:id
# Twitter Harvest v 2.2.8
# node:internal/process/promises:289
#             triggerUncaughtException(err, true /* fromPromise */);
#             ^
#
# page.screenshot: Target page, context or browser has been closed
#     at /root/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:437:47
#     at step (/root/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:56:23)
#     at Object.throw (/root/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:37:53)
#     at rejected (/root/.npm/_npx/006edd9c57a6e29b/node_modules/tweet-harvest/dist/crawl.js:29:65)
#
# Node.js v20.11.1
# ^C

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=";")

# Display the DataFrame
display(df)
# Out:
#                          created_at               id_str  \
# 0    Sat Mar 02 06:12:23 +0000 2024  1763809558672424972
# 1    Sat Mar 02 06:02:11 +0000 2024  1763806990466449686
# 2    Sat Mar 02 05:57:14 +0000 2024  1763805746880459150
# 3    Sat Mar 02 05:56:01 +0000 2024  1763805440289440049
# 4    Sat Mar 02 05:55:47 +0000 2024  1763805379476263231
# ..                              ...                  ...
# 802  Mon Feb 26 08:53:09 +0000 2024  1762038077638545430
# 803  Mon Feb 26 08:48:13 +0000 2024  1762036837152133304
# 804  Mon Feb 26 08:46:28 +0000 2024  1762036397534478554
# 805  Mon Feb 26 08:44:34 +0000 2024  1762035916376309999
# 806  Mon Feb 26 08:44:01 +0000 2024  1762035779076022273
#
#                                              full_text  quote_count  \
# 0    Selamat ya, Ganjar-Anies kalah cantik  #Dukung...            0
# 1    @geloraco Judul berita ini menggiring opini An...            0
# 2    Sumpah ga percaya Ganjar dan Anies bisa kalah ...            0
# 3    @Erazaman31 @crynptr25 @geloraco Anies fix uda...            0
# 4    Kalah aja masih ngotot, apa ga malu tuh Ganjar...            0
# ..                                                 ...          ...
# 802  @soeyoto1 Anies  Ganjar cuma mengakui quick co...            0
# 803  Itu beda konsep Yang saya maksud gak semua hal...            0
# 804  @ri91722809 @msaid_didu Terus lho pikir ikut s...            0
# 805  @unmagnetism Udah kalah" Aja masih di serang 😭...            1
# 806  @Anak__Ogi ganjar di dki aja kalah sama anies ...            0
#
#      reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0              0              0               0   in  1710919199911186432
# 1              0              0               0   in  1753748017818238976
# 2              0              0               0   in  1711245043271659520
# 3              1              0               0   in  1167443958168866823
# 4              0              0               0   in  1711320678895636480
# ..           ...            ...             ...  ...                  ...
# 802            1              1               0   in  1517576896787410944
# 803            0              0               0   in  1014427336228237313
# 804            0              0               0   in  1563082822008840193
# 805            2              3              99   in   761239599205142528
# 806            0              0               1   in           3161692884
#
#      conversation_id_str         username  \
# 0    1763809558672424972    akmalfabilioo
# 1    1763549046332129416   kiswantokusnan
# 2    1763805746880459150      muhamadsrya
# 3    1763549046332129416          Winmo18
# 4    1763805379476263231   Aryacandratawa
# ..                   ...              ...
# 802  1761980533209465048         didik_lp
# 803  1762036837152133304  SPforSavePalest
# 804  1762014417263509914        123ardhan
# 805  1762033745845268730         dwinnura
# 806  1761761131163767133       YossieC777
#
#                                              tweet_url
# 0    https://twitter.com/akmalfabilioo/status/17638...
# 1    https://twitter.com/kiswantokusnan/status/1763...
# 2    https://twitter.com/muhamadsrya/status/1763805...
# 3    https://twitter.com/Winmo18/status/17638054402...
# 4    https://twitter.com/Aryacandratawa/status/1763...
# ..                                                 ...
# 802  https://twitter.com/didik_lp/status/1762038077...
# 803  https://twitter.com/SPforSavePalest/status/176...
# 804  https://twitter.com/123ardhan/status/176203639...
# 805  https://twitter.com/dwinnura/status/1762035916...
# 806  https://twitter.com/YossieC777/status/17620357...
#
# [807 rows x 12 columns]

# %%
# Cek jumlah data yang didapatkan

num_tweets = len(df)
print(f"Jumlah tweet dalam dataframe adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe adalah 777.
